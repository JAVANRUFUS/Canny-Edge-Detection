# %% [markdown]
# # WORKSHOP 03
# ## Canny-Edge-Detection
#
# **Name :** Javan Rufus J  **Reg. No :** 212224230104 **Slot No :** 26OD1143

# %%
import cv2
import matplotlib.pyplot as plt

# %%
image = cv2.imread("javan.jpeg")

# %%
plt.imshow(image[:,:,::-1])
plt.title("Original Image")
# Out:
# Text(0.5, 1.0, 'Original Image')

# %%
# Apply Gaussian Blur to reduce noise
blurred = cv2.GaussianBlur(image, (5, 5), 1.4)

# %%
plt.imshow(blurred[:,:,::-1])
plt.title("Gaussian Blurred")
# Out:
# Text(0.5, 1.0, 'Gaussian Blurred')

# %%
# Apply Canny Edge Detection
#Canny edge detection
edges = cv2.Canny(blurred, threshold1 = 180, threshold2 = 200)

# %%
plt.imshow(edges, cmap="gray")
plt.title("Canny Edge Detection")
# Out:
# Text(0.5, 1.0, 'Canny Edge Detection')

# %%
#Comparision of Images.
plt.figure(figsize=(12, 4))

plt.subplot(1, 3, 1)
plt.imshow(image[:,:,::-1])
plt.title("Original Image")
plt.axis("off")

plt.subplot(1, 3, 2)
plt.imshow(blurred[:,:,::-1])
plt.title("Gaussian Blurred")
plt.axis("off")

plt.subplot(1, 3, 3)
plt.imshow(edges, cmap="gray")
plt.title("Canny Edge Detection")
plt.axis("off")

plt.tight_layout()
plt.show()
